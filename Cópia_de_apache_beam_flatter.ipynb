# %% [markdown]
# <a href="https://colab.research.google.com/github/ReMeiradL/Apache_Beam/blob/main/C%C3%B3pia_de_apache_beam_flatter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#INSTALADOR PARA MÁQUINA VIRTUAL, EM MÁQUINA LOCAL NÃO COLOQUE [INTERATIVE]
# !pip install apache_beam[interative]
# Out:
# Requirement already satisfied: apache_beam[interative] in /usr/local/lib/python3.12/dist-packages (2.71.0)
# WARNING: apache-beam 2.71.0 does not provide the extra 'interative'
# Requirement already satisfied: cryptography<48.0.0,>=39.0.0 in /usr/local/lib/python3.12/dist-packages (from apache_beam[interative]) (43.0.3)
# Requirement already satisfied: envoy-data-plane<0.3.0 in /usr/local/lib/python3.12/dist-packages (from apache_beam[interative]) (0.2.6)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /usr/local/lib/python3.12/dist-packages (from apache_beam[interative]) (1.12.1)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /usr/local/lib/python3.12/dist-packages (from apache_beam[interative]) (0.20)
# Requirement already satisfied: grpcio!=1.48.0,!=1.59.*,!=1.60.*,!=1.61.*,!=1.62.0,!=1.62.1,<1.66.0,<2,>=1.33.1 in /usr/local/lib/python3.12/dist-packages (from apache_beam[interative]) (1.65.5)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /usr/local/lib/python3.12/dist-packages (from apache_beam[interative]) (0.22.0)
# Requirement already satisfied: jsonpickle<4.0.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from apache_beam[interative]) (3.4.2)
# Requirement already satisfied: numpy<2.5.0,>=1.14.3 in /usr/local/lib/python3.12/dist-packages (from apache_beam[interative]) (2.0.2)
# Requirement already satisfied: objsize<0.8.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from apache_beam[interative]) (0.7.1)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.12/dist-packages (from apache_beam[interative]) (26.0)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from apache_beam[interative]) (4.16.0)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from apache_beam[interative]) (1.27.1)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.*,<7.0.0.dev0,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from apache_beam[interative]) (5.29.6)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from apache_beam[interative]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.12/dist-packages (from apache_beam[interative]) (2025.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /usr/local/lib/python3.12/dist-packages (from apache_beam[interative]) (2.32.4)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from apache_beam[interative]) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from apache_beam[interative]) (4.15.0)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from apache_beam[interative]) (0.25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=3.12 in /usr/local/lib/python3.12/dist-packages (from apache_beam[interative]) (6.0.3)
# Requirement already satisfied: beartype<0.23.0,>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from apache_beam[interative]) (0.22.9)
# Requirement already satisfied: pyarrow<19.0.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from apache_beam[interative]) (18.1.0)
# Requirement already satisfied: pyarrow-hotfix<1 in /usr/local/lib/python3.12/dist-packages (from apache_beam[interative]) (0.7)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography<48.0.0,>=39.0.0->apache_beam[interative]) (2.0.0)
# Requirement already satisfied: betterproto<3.0.0,>=2.0.0b3 in /usr/local/lib/python3.12/dist-packages (from envoy-data-plane<0.3.0->apache_beam[interative]) (2.0.0b6)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.12/dist-packages (from httplib2<0.23.0,>=0.8->apache_beam[interative]) (3.3.2)
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in /usr/local/lib/python3.12/dist-packages (from pymongo<5.0.0,>=3.8.0->apache_beam[interative]) (2.8.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3,>=2.8.0->apache_beam[interative]) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->apache_beam[interative]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->apache_beam[interative]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->apache_beam[interative]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->apache_beam[interative]) (2026.1.4)
# Requirement already satisfied: grpclib<0.5.0,>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from betterproto<3.0.0,>=2.0.0b3->envoy-data-plane<0.3.0->apache_beam[interative]) (0.4.9)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography<48.0.0,>=39.0.0->apache_beam[interative]) (3.0)
# Requirement already satisfied: h2<5,>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from grpclib<0.5.0,>=0.4.1->betterproto<3.0.0,>=2.0.0b3->envoy-data-plane<0.3.0->apache_beam[interative]) (4.3.0)
# Requirement already satisfied: multidict in /usr/local/lib/python3.12/dist-packages (from grpclib<0.5.0,>=0.4.1->betterproto<3.0.0,>=2.0.0b3->envoy-data-plane<0.3.0->apache_beam[interative]) (6.7.1)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3.1.0->grpclib<0.5.0,>=0.4.1->betterproto<3.0.0,>=2.0.0b3->envoy-data-plane<0.3.0->apache_beam[interative]) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3.1.0->grpclib<0.5.0,>=0.4.1->betterproto<3.0.0,>=2.0.0b3->envoy-data-plane<0.3.0->apache_beam[interative]) (4.1.0)

# %%
#IMPORT BIBLIOTECA
import apache_beam as beam
# Out:
# WARNING:root:crcmod package not found. This package is required if python-snappy or google-crc32c are not installed. To ensure crcmod is installed, install the tfrecord extra: pip install apache-beam[tfrecord]

# %%
p1 = beam.Pipeline()

negros = ('João', 'Maria', 'José')
brancos = ('Pedro', 'Ana', 'Paulo')
indios = ('Alice', 'Lucas', 'Bruna')

negros_pc = ( #cluesterização; pc = pcollection
    p1
    |"Criar PColletion negros" >> beam.Create(negros)
    )
brancos_pc = (
    p1
    |"Criar PColletion brancos" >> beam.Create(brancos)
    )
indios_pc = (
    p1
    |"Criar PColletion indios" >> beam.Create(indios)
    )

pessoas = ( #compilando os cluesters
    (negros_pc, brancos_pc, indios_pc)
    #é usada para unir várias PCollection em uma única PCollection.
    |"Unir PColletions" >> beam.Flatten() # Flatten é um "union"
    |"Mostrar dados" >> beam.Map(print)
)

p1.run()
# Out:
# WARNING:apache_beam.runners.interactive.interactive_environment:Dependencies required for Interactive Beam PCollection visualization are not available, please use: `pip install apache-beam[interactive]` to install necessary dependencies to enable all data visualization features.
# João
# Maria
# José
# Alice
# Lucas
# Bruna
# Pedro
# Ana
# Paulo
